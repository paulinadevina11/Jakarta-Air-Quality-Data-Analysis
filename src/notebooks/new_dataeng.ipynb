# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import f1_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv("/Users/paulinadevinawijaya/Downloads/ARKAVIDIA 10.0 - DSC/data/main_csv/data_collation_reset_v3.csv")
df.head()
# Out:
#    periode_data     tanggal               stasiun  pm_sepuluh  pm_duakomalima  \
# 0        201001  2010-01-01    DKI5 (Kebon Jeruk)         NaN             NaN
# 1        201001  2010-01-01    DKI1 (Bunderan HI)        60.0             NaN
# 2        201001  2010-01-01   DKI4 (Lubang Buaya)         NaN             NaN
# 3        201001  2010-01-01  DKI2 (Kelapa Gading)         NaN             NaN
# 4        201001  2010-01-01      DKI3 (Jagakarsa)         NaN             NaN
#
#    sulfur_dioksida  karbon_monoksida  ozon  nitrogen_dioksida   max  \
# 0              NaN               NaN   NaN                NaN   0.0
# 1              4.0              73.0  27.0               14.0  73.0
# 2              NaN               NaN   NaN                NaN   0.0
# 3              NaN               NaN   NaN                NaN   0.0
# 4              NaN               NaN   NaN                NaN   0.0
#
#   parameter_pencemar_kritis        kategori stasiun_id  is_holiday_nasional  \
# 0                       NaN  TIDAK ADA DATA       DKI5                    1
# 1                        CO          SEDANG       DKI1                    1
# 2                       NaN  TIDAK ADA DATA       DKI4                    1
# 3                       NaN  TIDAK ADA DATA       DKI2                    1
# 4                       NaN  TIDAK ADA DATA       DKI3                    1
#
#    is_weekend  temperature_2m_mean  relative_humidity_2m_mean  \
# 0           0                26.48                       82.2
# 1           0                26.48                       82.2
# 2           0                26.48                       82.2
# 3           0                26.48                       82.2
# 4           0                26.48                       82.2
#
#    wind_speed_10m_mean  precipitation_sum
# 0                10.54               4.48
# 1                10.54               4.48
# 2                10.54               4.48
# 3                10.54               4.48
# 4                10.54               4.48

# %% [markdown]
# # Basic Clean

# %%
df["tanggal"] = pd.to_datetime(df["tanggal"], errors="coerce")
df = df.dropna(subset=["tanggal"])

df = (
    df.sort_values(["stasiun", "tanggal"])
      .drop_duplicates(subset=["stasiun", "tanggal"])
      .reset_index(drop=True)
)

print(df["tanggal"].isna().sum())
df.head(10)
# Out:
# 0
#    periode_data    tanggal stasiun  pm_sepuluh  pm_duakomalima  \
# 0        201105 2011-01-05    DKI1        71.0             NaN
# 1        201101 2011-02-01    DKI1        35.0             NaN
# 2        201101 2011-03-01    DKI1        41.0             NaN
# 3        201105 2011-03-05    DKI1        69.0             NaN
# 4        201104 2011-09-04    DKI1        50.0             NaN
# 5        201110 2011-10-10    DKI1        83.0             NaN
# 6        201202 2012-02-02    DKI1        54.0             NaN
# 7        201201 2012-03-01    DKI1        65.0             NaN
# 8        201202 2012-03-02    DKI1        55.0             NaN
# 9        201203 2012-03-03    DKI1        56.0             NaN
#
#    sulfur_dioksida  karbon_monoksida   ozon  nitrogen_dioksida    max  \
# 0             18.0              54.0   88.0               31.0   88.0
# 1             15.0              15.0   47.0               11.0   47.0
# 2             16.0              35.0   31.0               15.0   41.0
# 3             22.0              31.0   69.0               28.0   69.0
# 4             21.0              33.0   44.0               14.0   50.0
# 5             16.0              34.0  107.0               19.0  107.0
# 6             52.0              34.0   74.0               17.0   74.0
# 7             15.0              42.0   86.0               22.0   86.0
# 8             31.0              44.0   59.0               14.0   59.0
# 9             25.0              51.0   76.0               17.0   76.0
#
#   parameter_pencemar_kritis     kategori stasiun_id  is_holiday_nasional  \
# 0                        O3       SEDANG        NaN                    0
# 1                        O3         BAIK        NaN                    0
# 2                      PM10         BAIK        NaN                    0
# 3                      PM10       SEDANG        NaN                    1
# 4                      PM10         BAIK        NaN                    0
# 5                        O3  TIDAK SEHAT        NaN                    0
# 6                        O3       SEDANG        NaN                    0
# 7                        O3       SEDANG        NaN                    0
# 8                        O3       SEDANG        NaN                    0
# 9                        O3       SEDANG        NaN                    0
#
#    is_weekend  temperature_2m_mean  relative_humidity_2m_mean  \
# 0           0                25.36                       86.4
# 1           0                25.14                       88.6
# 2           0                24.66                       85.6
# 3           1                25.34                       85.4
# 4           1                27.32                       70.4
# 5           0                26.86                       80.2
# 6           0                25.48                       88.0
# 7           0                25.26                       89.4
# 8           0                26.16                       84.2
# 9           1                26.72                       80.6
#
#    wind_speed_10m_mean  precipitation_sum
# 0                 5.48               6.82
# 1                 8.86              16.02
# 2                13.90               6.34
# 3                 9.68               6.40
# 4                 6.56               0.00
# 5                 4.10               3.86
# 6                 5.90              22.96
# 7                 5.54              17.00
# 8                 8.26               6.66
# 9                 9.24               2.10

# %% [markdown]
# # Basic Time Features

# %%
df["dayofweek"] = df["tanggal"].dt.dayofweek
df["is_weekend"] = df["dayofweek"].isin([5,6]).astype(int)
df["month"] = df["tanggal"].dt.month

# %% [markdown]
# # Defining the Numeric Core

# %%
base_pollutants = [
    "pm_sepuluh",
    "pm_duakomalima",
    "sulfur_dioksida",
    "karbon_monoksida",
    "ozon",
    "nitrogen_dioksida"
]

cuaca_cols = [
    "temperature_2m_mean",
    "relative_humidity_2m_mean",
    "wind_speed_10m_mean",
    "precipitation_sum"
]

# %% [markdown]
# # Lag Features

# %%
for lag in [1, 3, 7]:
    df[f"pm25_lag_{lag}"] = (
        df.groupby("stasiun")["pm_duakomalima"]
          .shift(lag)
    )

# %% [markdown]
# # Rolling Feature (Decreasing Noise)

# %%
df["pm25_roll_3"] = (
    df.groupby("stasiun")["pm_duakomalima"]
      .shift(1)
      .rolling(3)
      .mean()
)

# %%
print(df.columns.tolist())
# Out:
# ['periode_data', 'tanggal', 'stasiun', 'pm_sepuluh', 'pm_duakomalima', 'sulfur_dioksida', 'karbon_monoksida', 'ozon', 'nitrogen_dioksida', 'max', 'parameter_pencemar_kritis', 'kategori', 'stasiun_id', 'is_holiday_nasional', 'is_weekend', 'temperature_2m_mean', 'relative_humidity_2m_mean', 'wind_speed_10m_mean', 'precipitation_sum', 'dayofweek', 'month', 'pm25_lag_1', 'pm25_lag_3', 'pm25_lag_7', 'pm25_roll_3']

# %% [markdown]
# # Handle Missing Data

# %%
num_cols = (
    base_pollutants +
    cuaca_cols +
    ["pm25_lag_1", "pm25_lag_3", "pm25_lag_7", "pm25_roll_3"]
)

# %%
df = df.rename(columns={
    "temperature_2m_mean (°C)": "temperature_2m_mean",
    "relative_humidity_2m_mean (%)": "relative_humidity_2m_mean",
    "wind_speed_10m_mean (km/h)": "wind_speed_10m_mean",
    "precipitation_sum (mm)": "precipitation_sum"
})

# %%
df[num_cols] = (
    df.groupby("stasiun")[num_cols]
      .transform(lambda x: x.fillna(x.median()))
)

# %%
print(df[num_cols].isna().sum().sum())
print(df.shape)
# Out:
# 19735
# (8817, 25)

# %%
core_features = (
    base_pollutants +
    cuaca_cols +
    ["pm25_lag_1", "pm25_lag_3", "pm25_lag_7", "pm25_roll_3"]
)

# %%
before = df.shape[0]

df = df.dropna(subset=core_features)

after = df.shape[0]

print(f"Dropped rows: {before - after}")
print("New shape:", df.shape)
# Out:
# Dropped rows: 3947
# New shape: (4870, 25)

# %%
print("Total NaN (numeric):", df[core_features].isna().sum().sum())
print("Shape:", df.shape)
# Out:
# Total NaN (numeric): 0
# Shape: (4870, 25)

# %%
core_features = (
    base_pollutants +
    cuaca_cols +
    ["pm25_lag_1", "pm25_lag_3", "pm25_lag_7", "pm25_roll_3"]
)

print("NaN before:", df[core_features].isna().sum().sum())

df = df.dropna(subset=core_features).reset_index(drop=True)

print("NaN after:", df[core_features].isna().sum().sum())
print("Shape:", df.shape)
# Out:
# NaN before: 0
# NaN after: 0
# Shape: (4870, 25)

# %% [markdown]
# # Encoding

# %%
le_stasiun = LabelEncoder()
le_target = LabelEncoder()

df["stasiun_enc"] = le_stasiun.fit_transform(df["stasiun"])
df["kategori_enc"] = le_target.fit_transform(df["kategori"])

# %% [markdown]
# # Outlier Handling

# %%
def iqr_cap(df, cols, factor=1.5):
    df = df.copy()
    for col in cols:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - factor * IQR
        upper = Q3 + factor * IQR
        df[col] = df[col].clip(lower, upper)
    return df

continuous_cols = (
    base_pollutants +
    cuaca_cols +
    ["pm25_lag_1", "pm25_lag_3", "pm25_lag_7", "pm25_roll_3"]
)

df = iqr_cap(df, continuous_cols)

# %% [markdown]
# # Scaling (Normalization)

# %%
scaler = RobustScaler()

df_scaled = df.copy()
df_scaled[continuous_cols] = scaler.fit_transform(
    df_scaled[continuous_cols]
)

# %% [markdown]
# # Encoder

# %%
le_station = LabelEncoder()
df_scaled["stasiun_enc"] = le_station.fit_transform(df_scaled["stasiun"])

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Pollution intensity Ratio

# %%
df_scaled["pm25_pm10_ratio"] = (
    df_scaled["pm_duakomalima"] /
    (df_scaled["pm_sepuluh"] + 1e-6)
)

# %% [markdown]
# ## Weather Pollution Interaction

# %%
df_scaled["pm25_temp_interaction"] = (
    df_scaled["pm_duakomalima"] *
    df_scaled["temperature_2m_mean"]
)

df_scaled["pm25_wind_inverse"] = (
    df_scaled["pm_duakomalima"] /
    (df_scaled["wind_speed_10m_mean"] + 1)
)

# %% [markdown]
# ## Temporal Cycling Encoding

# %%
df_scaled["month_sin"] = np.sin(2 * np.pi * df_scaled["month"] / 12)
df_scaled["month_cos"] = np.cos(2 * np.pi * df_scaled["month"] / 12)

df_scaled["dow_sin"] = np.sin(2 * np.pi * df_scaled["dayofweek"] / 7)
df_scaled["dow_cos"] = np.cos(2 * np.pi * df_scaled["dayofweek"] / 7)

# %%
print("Final NaN count:", df_scaled.isna().sum().sum())
print("Final shape:", df_scaled.shape)
# Out:
# Final NaN count: 4955
# Final shape: (4870, 34)

# %%
nan_cols = (
    df_scaled.isna()
    .sum()
    .sort_values(ascending=False)
)

nan_cols[nan_cols > 0]
# Out:
# stasiun_id                   4870
# parameter_pencemar_kritis      75
# max                            10
# dtype: int64

# %% [markdown]
# # Handling Missing Value

# %%
df = df.drop(columns=["stasiun_id"], errors="ignore")

df["parameter_pencemar_kritis"] = (
    df["parameter_pencemar_kritis"]
    .fillna("TIDAK_DOMINAN")
)

# %%
print("Final NaN count:", df.isna().sum().sum())
print("Final shape:", df.shape)
# Out:
# Final NaN count: 10
# Final shape: (4870, 26)

# %%
df.isna().sum()[df.isna().sum() > 0]
# Out:
# max    10
# dtype: int64

# %%
df["max"] = (
    df.groupby("stasiun")["max"]
      .transform(lambda x: x.fillna(x.median()))
)

df["max"] = df["max"].fillna(df["max"].median())

# %%
print("Final NaN count:", df.isna().sum().sum())
df.isna().sum()[df.isna().sum() > 0]
# Out:
# Final NaN count: 0
# Series([], dtype: int64)

# %%
print("Final shape:", df.shape)
print("Final NaN count:", df.isna().sum().sum())
# Out:
# Final shape: (4870, 26)
# Final NaN count: 0

# %%
df = df.reset_index(drop=True)

# %%
SAVE_PATH = "data_collation_catboost_ready.csv"

df.to_csv(
    SAVE_PATH,
    index=False
)

print(f"Dataset saved to {SAVE_PATH}")
# Out:
# ✅ Dataset saved to data_collation_catboost_ready.csv
